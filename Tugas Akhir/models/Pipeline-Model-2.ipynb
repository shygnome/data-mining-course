# %% [markdown]
# # Model Pipeline

# %% [markdown]
# This notebook is used for training candidate models for air quality dataset.

# %%
MODEL_NAME = 'LSTM'

# %% [markdown]
# ## Modules

# %%
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import cross_val_score, train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Ensuring reproducibility

# %%
CUSTOM_SEED = 42
np.random.seed(CUSTOM_SEED)

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Load Dataset

# %%
path = '../dataset/Air quality/'
dataset = pd.read_csv(path + 'cleansed_air_quality.csv')
dataset = dataset.set_index('date')
dataset
# Out:
#                      PM2.5  PM10   SO2   NO2      CO    O3  TEMP    PRES  \
# date
# 2013-03-01 00:00:00    7.0   7.0   3.0   2.0   100.0  91.0  -2.3  1020.3
# 2013-03-01 00:00:00    4.0   4.0   4.0   7.0   300.0  77.0  -0.7  1023.0
# 2013-03-01 00:00:00    8.0   8.0   6.0  28.0   400.0  52.0  -0.7  1023.0
# 2013-03-01 00:00:00    3.0   6.0  13.0   7.0   300.0  85.0  -2.3  1020.8
# 2013-03-01 00:00:00    4.0   4.0  14.0  20.0   300.0  69.0  -0.7  1023.0
# ...                    ...   ...   ...   ...     ...   ...   ...     ...
# 2017-02-28 23:00:00   15.0  22.0  13.0  34.0   500.0  60.0   7.4  1014.9
# 2017-02-28 23:00:00   20.0  25.0   6.0  28.0   900.0  54.0   7.0  1009.4
# 2017-02-28 23:00:00   10.0  28.0   7.0  48.0   600.0  39.0   8.6  1014.1
# 2017-02-28 23:00:00   15.0  27.0   5.0  53.0   600.0  33.0   8.6  1014.1
# 2017-02-28 23:00:00   30.0  71.0  11.0  87.0  1200.0   4.0   8.6  1014.1
#
#                      DEWP  RAIN   wd  WSPM       station
# date
# 2013-03-01 00:00:00 -20.7   0.0  WNW   3.1       Huairou
# 2013-03-01 00:00:00 -18.8   0.0  NNW   4.4  Aotizhongxin
# 2013-03-01 00:00:00 -18.8   0.0  NNW   4.4        Wanliu
# 2013-03-01 00:00:00 -19.7   0.0    E   0.5     Changping
# 2013-03-01 00:00:00 -18.8   0.0  NNW   4.4      Guanyuan
# ...                   ...   ...  ...   ...           ...
# 2017-02-28 23:00:00 -11.9   0.0    N   1.4        Shunyi
# 2017-02-28 23:00:00 -12.2   0.0    N   1.9     Changping
# 2017-02-28 23:00:00 -15.9   0.0  NNE   1.3  Nongzhanguan
# 2017-02-28 23:00:00 -15.9   0.0  NNE   1.3      Guanyuan
# 2017-02-28 23:00:00 -15.9   0.0  NNE   1.3        Dongsi
#
# [313319 rows x 13 columns]

# %%
np.unique(dataset['station'])
# Out:
# array(['Aotizhongxin', 'Changping', 'Dingling', 'Dongsi', 'Guanyuan',
#        'Gucheng', 'Huairou', 'Nongzhanguan', 'Shunyi', 'Tiantan',
#        'Wanliu', 'Wanshouxigong'], dtype=object)

# %%
dataset[dataset.station == 'Guanyuan']
# Out:
#                      PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  DEWP  \
# date
# 2013-03-01 00:00:00    4.0   4.0  14.0  20.0  300.0  69.0  -0.7  1023.0 -18.8
# 2013-03-01 01:00:00    4.0   4.0  13.0  17.0  300.0  72.0  -1.1  1023.2 -18.2
# 2013-03-01 03:00:00    3.0   6.0   7.0  24.0  400.0  62.0  -1.4  1024.5 -19.4
# 2013-03-01 04:00:00    3.0   6.0   5.0  14.0  400.0  71.0  -2.0  1025.2 -19.5
# 2013-03-01 05:00:00    3.0   6.0   6.0  14.0  400.0  71.0  -2.2  1025.6 -19.6
# ...                    ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2017-02-28 19:00:00   13.0  37.0   3.0  36.0  400.0  60.0  12.5  1013.5 -16.2
# 2017-02-28 20:00:00   20.0  43.0   4.0  48.0  500.0  43.0  11.6  1013.6 -15.1
# 2017-02-28 21:00:00   16.0  33.0   5.0  39.0  500.0  50.0  10.8  1014.2 -13.3
# 2017-02-28 22:00:00   11.0  24.0   5.0  47.0  500.0  41.0  10.5  1014.4 -12.9
# 2017-02-28 23:00:00   15.0  27.0   5.0  53.0  600.0  33.0   8.6  1014.1 -15.9
#
#                      RAIN   wd  WSPM   station
# date
# 2013-03-01 00:00:00   0.0  NNW   4.4  Guanyuan
# 2013-03-01 01:00:00   0.0    N   4.7  Guanyuan
# 2013-03-01 03:00:00   0.0   NW   3.1  Guanyuan
# 2013-03-01 04:00:00   0.0    N   2.0  Guanyuan
# 2013-03-01 05:00:00   0.0    N   3.7  Guanyuan
# ...                   ...  ...   ...       ...
# 2017-02-28 19:00:00   0.0   NW   2.4  Guanyuan
# 2017-02-28 20:00:00   0.0  WNW   0.9  Guanyuan
# 2017-02-28 21:00:00   0.0   NW   1.1  Guanyuan
# 2017-02-28 22:00:00   0.0  NNW   1.2  Guanyuan
# 2017-02-28 23:00:00   0.0  NNE   1.3  Guanyuan
#
# [26408 rows x 13 columns]

# %% [markdown]
# ### Splitting Dataset

# %%
# Split dataset
feat_cols = ["PM10", "SO2", "NO2", "CO", "O3", "TEMP", "PRES", "DEWP", "RAIN", "wd", "WSPM", "station"]
excluded_cols = []
target = "PM2.5"
X, y = dataset[feat_cols], dataset[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print ("Ukuran data training {}, data testing {}".format(X_train.shape, X_test.shape))
# Out:
# Ukuran data training (249613, 14), data testing (62404, 14)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Load Models

# %% [markdown]
# Please copy your models here as a function.

# %%
# define base model
def baseline_model(input_dim):
    def _model():
        # create model
        model = Sequential()
        model.add(Dense(50, input_dim=input_dim, kernel_initializer='normal', activation='relu'))
        model.add(Dense(1, kernel_initializer='normal'))
        # Compile model
        model.compile(loss='mean_squared_error', optimizer='adam')
        return model
    return _model

# %%
baseline_model(16)
# Out:
# <function __main__.baseline_model.<locals>._model()>

# %% [markdown]
# ## Run Pipeline

# %%
# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=baseline_model(X_train.shape[1]), epochs=50, batch_size=5, verbose=1)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10)
results = cross_val_score(pipeline, X_train, y_train, cv=kfold)
print("Larger: %.2f (%.2f) MSE" % (results.mean(), results.std()))

# %% [markdown]
# ## Evaluation
